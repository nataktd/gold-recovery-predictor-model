# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-и-подготовка-к-работе" data-toc-modified-id="Изучение-данных-и-подготовка-к-работе-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных и подготовка к работе</a></span><ul class="toc-item"><li><span><a href="#Переменные-константы,-функции-и-формулы-для-расчетов" data-toc-modified-id="Переменные-константы,-функции-и-формулы-для-расчетов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Переменные константы, функции и формулы для расчетов</a></span></li><li><span><a href="#Общая-информация-о-датасетах-и-данных" data-toc-modified-id="Общая-информация-о-датасетах-и-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Общая информация о датасетах и данных</a></span></li><li><span><a href="#Проверка-правильности-расчета-эффективность-обогащения." data-toc-modified-id="Проверка-правильности-расчета-эффективность-обогащения.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка правильности расчета эффективность обогащения.</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-изменения-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Анализ-изменения-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ изменения концентрация металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Анализ-распределения-размеров-гранул-исходного-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Анализ-распределения-размеров-гранул-исходного-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Анализ распределения размеров гранул исходного сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Суммарная-концентрация-металлов-на-разных-стадиях:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате." data-toc-modified-id="Суммарная-концентрация-металлов-на-разных-стадиях:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Метрики" data-toc-modified-id="Метрики-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Метрики</a></span></li><li><span><a href="#Обучение-моделей-и-оценка-их-качества-кросс-валидацией" data-toc-modified-id="Обучение-моделей-и-оценка-их-качества-кросс-валидацией-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение моделей и оценка их качества кросс-валидацией</a></span></li><li><span><a href="#Проверка-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-модели-на-тестовой-выборке-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Проверка модели на тестовой выборке</a></span></li></ul></li><li><span><a href="#Итоги-и-выводы-по-проекту" data-toc-modified-id="Итоги-и-выводы-по-проекту-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Итоги и выводы по проекту</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# В нашем распоряжении сырые данные (их просто выгрузили из хранилища) с параметрами добычи и очистки золотосодержащей руды.
#
# Необходимо подготовить прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.

# %% [markdown]
# # Цель:

# %% [markdown]
# Нам нужно смоделировать процесс восстановления золота из золотосодержащей руды.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.

# %% [markdown]
# # Технологический процесс

# %% [markdown]
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь.
#
# Её отправляют на флотацию (обогащение) и двухэтапную очистку.
#
# Опишем каждую стадию:
#
# - Флотация
#
#     - Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов. На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# - Очистка
#
#     - Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# # Описание данных:

# %% [markdown]
# Данные находятся в трёх файлах:
#
# - `gold_recovery_train.csv` — обучающая выборка;
#
# - `gold_recovery_test.csv` — тестовая выборка;
#
# - `gold_recovery_full.csv` — исходные данные.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# Данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи.
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# **Технологический процесс**
#
# - `Rougher feed` — исходное сырье
#
# - `Rougher additions` (или `reagent additions`) — флотационные реагенты: `Xanthate`, `Sulphate`, `Depressant`
#
#     - `Xanthate **` — ксантогенат (промотер, или активатор флотации);
#
#     - `Sulphate` — сульфат (на данном производстве сульфид натрия);
#
#     - `Depressant` — депрессант (силикат натрия)
#
# - `Rougher process` (англ. «грубый процесс») — флотация
#
# - `Rougher tails` — отвальные хвосты
#
# - `Float banks` — флотационная установка
#
# - `Cleaner process` — очистка
#
# - `Rougher Au` — черновой концентрат золота
#
# - `Final Au` — финальный концентрат золота
#
# **Параметры этапов**
#
# - `air amount` — объём воздуха
#
# - `fluid levels` — уровень жидкости
#
# - `feed size` — размер гранул сырья
#
# - `feed rate` — скорость подачи
#
# **Наименование признаков**
#
# Наименование признаков должно быть такое:
#
# `[этап].[тип_параметра].[название_параметра]`
#
# Пример: `rougher.input.feed_ag`
#
# **Возможные значения для блока [этап]:**
#
# - `rougher` — флотация
#
# - `primary_cleaner` — первичная очистка
#
# - `secondary_cleaner` — вторичная очистка
#
# - `final` — финальные характеристики
#
# **Возможные значения для блока [тип_параметра]:**
#
# - `input` — параметры сырья
#
# - `output` — параметры продукта
#
# - `state` — параметры, характеризующие текущее состояние этапа
#
# - `calculation` — расчётные характеристики

# %% [markdown]
# # Краткий план работы:

# %% [markdown]
# - Подготовить данные.
#
#     - Открыть файлы и изучити их.
#
# - Проверить, что эффективность обогащения рассчитана правильно.
#
#     - Вычислить её на обучающей выборке для признака `rougher.output.recovery`.
#
#     - Найти `MAE` между нашими расчётами и значением признака.
#
#     - Подготовить выводы.
#
# - Проанализировать признаки, недоступные в тестовой выборке.
#
#     - Ответить на вопросы:Что это за параметры? К какому типу относятся?
#
# - Провести предобработку данных.
#
# - Проанализовать данные.
#
# - Посмотреть, как меняется концентрация металлов (`Au`, `Ag`, `Pb`) на различных этапах очистки.
#
#     - Подготовить выводы.
#
# - Сравнить распределения размеров гранул сырья на обучающей и тестовой выборках (если распределения сильно отличаются друг от друга, оценка модели будет неправильной).
#
# - Исследовать суммарную концентрацию всех веществ на разных стадиях:
#
#     - в сырье,
#
#     - в черновом,
#
#     - финальном концентратах.
#
#     - Определить есть ли аномальные значения в суммарном распределении или нет. Если они есть, принять обоснованное решение удалять из обеих выборок или нет.
#
#     - Подготовить выводы и удалить аномалии.
#
# - Построить модель.
#
# - Написать функцию для вычисления итоговой `sMAPE`.
#
# - Обучить разные модели и оцените их качество кросс-валидацией. Выберать лучшую модель и проверьть её на тестовой выборке.
#
# - Подготовить выводы.

# %% [markdown]
# ## Изучение данных и подготовка к работе

# %% [markdown]
# Настроим окружение: импортируем все необходимые библиотеки.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.preprocessing import StandardScaler

from sklearn.dummy import DummyRegressor


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Переменные константы, функции и формулы для расчетов

# %%
STATE = np.random.RandomState(123)
TARGETS = ['rougher.output.recovery', 'final.output.recovery']
METALS = ['au', 'ag', 'pb']
CONCENTRATE_METRICS = ['rougher.input.feed', 'rougher.output.concentrate', 
                       'primary_cleaner.output.concentrate', 'final.output.concentrate']

# %%
# метод для подсчета количества строк, столбцов и пустых значений в колонках
def info_columns_nan(df):    
    print('Количество объектов - строк в датафрейме', df.shape[0])    
    print('Количество столбцов-признаков в датафрейме', df.shape[1])    
    print('___________________________________________')    
    print('Типы данных')    
    print(df.dtypes.value_counts())    
    print('___________________________________________')    
    print('Количество строк - объектов с пропусками', df.isnull().sum().sum())    
    print('Процент пропусков по всему датафрейму', (df.isnull().sum().sum ()/len(df)*100).round(2))      
    return pd.DataFrame({'процент пропусков':round((df.isna().mean()*100),),
                         'количество пропусков': df.isnull().sum()}).sort_values(by = 'процент пропусков').tail(15)

# %%
#  метод построит distplot распределения концентраций металов на различных этапах
def distplot_metals(argument_1, argument_2):
    fig, axes = plt.subplots(1, len(argument_1), figsize=(15, 5), constrained_layout=True)
    fig.suptitle('Концентрация металлов на различных этапах', fontsize=24)    
    # перебираем значения процессов (или название металлов)
    for arg_1, ax in zip(argument_1, axes):    
        ax.set_title(arg_1)    
        # перебираем название металлов (или значения процессов)
        for arg_2 in argument_2:             
            if len(arg_1) > len(arg_2):        
                cols = df_train.columns.str.contains(arg_1 + '_' + arg_2)            
            elif len(arg_1) < len(arg_2):                
                cols = df_train.columns.str.contains(arg_2 + '_' + arg_1)        
            # строим distplot 4 график по процессам (или 3 графика по металлам)
            sns_ax = sns.distplot(df_train.loc[:, cols], bins = 50, label = arg_2, ax = ax)         
    plt.legend()
    plt.show()

# %%
# метод для постоения графика частоты по двум выборкам
def hist_columns(df_columns_1, df_columns_2, label_x, title_part):
    df_columns_1.hist(bins=50, figsize=(15,5), color='c', alpha = 0.95, edgecolor='black', linewidth=1, legend=True)
    df_columns_2.hist(bins=50, figsize=(15,5), color='r', alpha = 0.55, edgecolor='black', linewidth=1, legend=True)
    plt.xlabel(label_x)    
    plt.ylabel('Частота')
    plt.title('Гистограмма распредления ' + title_part)
    plt.show()

# %%
#боксплот для признаков датафрейма
def boxplot_df(df, title):    
    names = df.columns
    ncols = len(names)    
    fig, axes = plt.subplots(1,ncols, figsize=(20, 5))    
    for name, ax in zip( names, axes.flatten()):        
        sns.boxplot(y=name, data=df, orient='v', ax=ax)        
        plt.suptitle(title)

# %%
# метод найдет, посчитает и удалит выбросы по заданным столбцам
def find_outliers(df,column, title):    
    # определим 25 и 75% квантили
    q25=np.array(df[column].quantile(0.25))    
    q75=np.array(df[column].quantile(0.75))
    
    # границы нормального размаха
    limit_of_normal_range_left=q25-1.5*(q75-q25)    
    limit_of_normal_range_right=q75+1.5*(q75-q25)
    
    # определим индексы объектов - выбросов
    del_index = []
        for index_value, value in zip(df[column].index,df[column]):        
        if limit_of_normal_range_right <= value or value <= limit_of_normal_range_left:            
            del_index.append(index_value)           
    
    print('Границы норамльного размаха', limit_of_normal_range_left.round(2),'-', limit_of_normal_range_right.round(2))    
    print('Количество строк, выбранных для удаления в столбце ', column, title, ': ', len(del_index))    
    print('Процент удаленных данных {:.2f}'.format(len(del_index)*100/df.shape[0]))    
    print('___________________________________________________________')    
    # удалим строки по индексу
    df = df.drop(index=del_index, axis = 0, inplace = True)    
    return df

# %%
#метод сгруппирует столбцы с высокой корреляцией, высчитаем среднее по столбцам
def change_to_mean(df, d_features):           
    for key, value in d_features.items():                  
        df[key] = df[value].mean(axis= 1)                    
        df = df.drop(value, axis = 1)           
    return  df

# %%
# Метод для подбора гиперпараметров алгоритма, вывод метрик, где
# df - это набор датасетов для обучения, model - алгоритм маш обучения, который будем использовать
def model_training(df, model, params, data_scaling, outlier, corr_param, algorithm):    
    cv =  KFold(n_splits=5, shuffle=False)      
    search1 = GridSearchCV(model, param_grid=params, cv=cv, scoring=smape_scorer)    
    search2 = GridSearchCV(model, param_grid=params, cv=cv, scoring=smape_scorer)
    search_rougher = search1.fit(df[0], df[1])    
    search_final = search2.fit(df[2], df[3])    
    # посчитаем итоговое sMAPE
    sMAPE_total_train = final_sMAPE(search_rougher.best_score_, search_final.best_score_)    
       
    print('Лучшее значение sMAPE : \
    rougher - {}, final - {} ' .format(-search_rougher.best_score_, -search_final.best_score_))    
    print('Лучшее значениях гиперпараметров: \
    rougher - {}, final - {}' .format(search_rougher.best_estimator_, search_final.best_estimator_))        
        
    # строка для накопительной таблицы по моделям и параметрам
    row_tab = [algorithm, data_scaling, outlier, corr_param, 
                          -search_rougher.best_score_, -search_final.best_score_, -sMAPE_total_train]    
    # метод возвращает строку с sMAPE для накопительной таблицы, лучшую модель
    return row_tab, search_rougher, search_final

# создаем накопительную таблицу для сбора данных по всем лучшим моделям алгоритма для сравнения
tab_train = pd.DataFrame(columns = ['Алгоритм модели',  'Масштабированы', 'Выбросы', 'Коллирнеарность', 
                                 'sMAPE_rougher_train', 'sMAPE_final_train', 'итоговое sMAPE_train'])

# %%
# метод проверит модели на тестовой выборке
def test_scorer(df_train, dt_test, model_rougher,  model_final, data_scaling, outlier, corr_param, algorithm):    
    # обучим модель на лучших гиперпараметрах
    model_rougher.fit(df_train[0], df_train[1])  
    predicted_rougher = model_rougher.predict(dt_test[0])    
    model_final.fit(df_train[2], df_train[3])    
    predicted_final = model_final.predict(dt_test[2])
    
    # получим метерики sMAPE
    sMAPE_rougher = sMAPE(dt_test[1], predicted_rougher)    
    sMAPE_final = sMAPE(dt_test[3], predicted_final)
    sMAPE_total = final_sMAPE(sMAPE_rougher,sMAPE_final)
    
    # строка для накопительной таблицы по моделям и параметрам
    row_tab = [algorithm, data_scaling, outlier, corr_param, sMAPE_rougher, sMAPE_final, sMAPE_total]   
    # метод возвращает строку с sMAPE для накопительной таблицы
    return row_tab

# создаем накопительную таблицу для сбора данных по всем лучшим моделям алгоритма  для сравнения
tab_test = pd.DataFrame(columns = ['Алгоритм модели',  'Масштабированы', 'Выбросы', 'Коллирнеарность', 
                                 'sMAPE_rougher', 'sMAPE_final', 'итоговое sMAPE'])

# %% [markdown]
# # Расчёт эффективности и метрика качества

# %% [markdown]
# **Эффективность обогащения рассчитывается по формуле **
#
# \begin{align}
# {Recovery} = \frac{C\times(F-T)}{F\times(C-T)}\times100\%
# \end{align}
#
#
#
# где:
#
# - `C` — доля золота в концентрате после флотации/очистки;
#
# - `F` — доля золота в сырье/концентрате до флотации/очистки;
#
# - `T` — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Важен не только финальный продукт, но и черновой концентрат.
#
# **Метрика качества**
#
# Для решения задачи введём новую метрику качества — `sMAPE` (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
#
# Она похожа на `MAE`, но выражается не в абсолютных величинах, а в относительных. Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
# Метрика `sMAPE` вычисляется так:
#
# \begin{align}
# {sMAPE} = \frac{1}{N} \sum_{i=1}^{N}\frac{|y_i-\hat{y_i}|}{(|y_i|+|\hat{y_i}|)/2}\times100\%
# \end{align}
#
#
# Нужно спрогнозировать сразу две величины:
#
# - эффективность обогащения чернового концентрата `rougher.output.recovery`;
#
# - эффективность обогащения финального концентрата `final.output.recovery`.
#
# Итоговая метрика складывается из двух величин:
#
# \begin{align}
# \frac {Итоговое} {sMAPE} = 25\% \times sMAPE(rougher) + 75\% \times sMAPE(final)
# \end{align}

# %% [markdown]
# <a id = 'df'></a>

# %% [markdown]
# ### Общая информация о датасетах и данных

# %% [markdown]
# Ознакомимся с данными таблиц и их структурой.
#
# Загрузим в датафреймы данные, с которыми будем работать.
#
# Посмотрим на несколько первых записей в датафреймах c помощью метода `head()`.
#
# Выведем общую информацию по таблицах c помощью метода `info()`.

# %%
pd.options.display.max_columns = None
try:    
    df_train = pd.read_csv('/datasets/gold_industry_train.csv', sep=',')
    df_test = pd.read_csv('/datasets/gold_industry_test.csv', sep=',')
    df_full = pd.read_csv('/datasets/gold_industry_full.csv', sep=',')    
except:    
    df_train = pd.read_csv('gold_industry_train.csv', sep=',')
    df_test = pd.read_csv('gold_industry_test.csv', sep=',')
    df_full = pd.read_csv('gold_industry_full.csv', sep=',') # для локальной работы

# %%
df_train.head(10).T
# Out:
#                                           0                    1  \
# date                    2016-01-15 00:00:00  2016-01-15 01:00:00
# rougher.input.feed_au               6.48615             6.478583
# rougher.input.feed_ag              6.100378             6.161113
# rougher.input.feed_pb              2.284912             2.266033
# rougher.input.feed_sol            36.808594            35.753385
# ...                                     ...                  ...
# final.output.recovery             70.541216            69.266198
# final.output.tail_au               2.143149              2.22493
# final.output.tail_ag              10.411962            10.462676
# final.output.tail_pb               0.895447             0.927452
# final.output.tail_sol             16.904297            16.634514
#
#                                           2                    3  \
# date                    2016-01-15 02:00:00  2016-01-15 03:00:00
# ...

# %%
df_test.head(10).T
# Out:
#                                                               0  \
# date                                        2017-12-09 14:59:59
# rougher.input.feed_au                                  4.365491
# rougher.input.feed_ag                                  6.158718
# rougher.input.feed_pb                                  3.875727
# rougher.input.feed_sol                                39.135119
# rougher.input.feed_rate                              555.820208
# rougher.input.feed_size                               94.544358
# rougher.input.floatbank10_sulfate                      6.146982
# rougher.input.floatbank10_xanthate                     9.308612
# rougher.state.floatbank10_a_air                     1196.238112
# rougher.state.floatbank10_a_level                   -299.862743
# rougher.state.floatbank10_b_air                     1147.248241
# rougher.state.floatbank10_b_level                   -500.363165
# rougher.state.floatbank10_c_air                     1047.279065
# ...

# %%
df_full.head(10).T
# Out:
#                                           0                    1  \
# date                    2016-01-15 00:00:00  2016-01-15 01:00:00
# rougher.input.feed_au               6.48615             6.478583
# rougher.input.feed_ag              6.100378             6.161113
# rougher.input.feed_pb              2.284912             2.266033
# rougher.input.feed_sol            36.808594            35.753385
# ...                                     ...                  ...
# final.output.recovery             70.541216            69.266198
# final.output.tail_au               2.143149              2.22493
# final.output.tail_ag              10.411962            10.462676
# final.output.tail_pb               0.895447             0.927452
# final.output.tail_sol             16.904297            16.634514
#
#                                           2                    3  \
# date                    2016-01-15 02:00:00  2016-01-15 03:00:00
# ...

# %% [markdown]
# Так как в каждом дата фрейме много столбцов метод `info()` для получения сведений о типах, пропусках, размере датафреймов использоватеть не будем. Рассмотрим данные о размере датафреймов, типах данных и количество пропусков по столбцам в каждом датафрейме вызвав метод `info_columns_nan()`.

# %%
info_columns_nan(df_train)
# Out:
# Количество объектов - строк в датафрейме 14579
# Количество столбцов-признаков в датафрейме 87
# ___________________________________________
# Типы данных
# float64    86
# object      1
# dtype: int64
# ___________________________________________
# Количество строк - объектов с пропусками 3050
# Процент пропусков по всему датафрейму 20.92
#                                                     процент пропусков  \
# rougher.output.concentrate_au                                     0.0
# rougher.calculation.au_pb_ratio                                   0.0
# rougher.calculation.floatbank11_sulfate_to_au_feed                0.0
# rougher.calculation.floatbank10_sulfate_to_au_feed                0.0
# rougher.output.concentrate_pb                                     0.0
# primary_cleaner.output.concentrate_pb                             1.0
# secondary_cleaner.state.floatbank2_a_air                          1.0
# rougher.input.feed_size                                           1.0
# ...

# %%
info_columns_nan(df_test)
# Out:
# Количество объектов - строк в датафрейме 4860
# Количество столбцов-признаков в датафрейме 53
# ___________________________________________
# Типы данных
# float64    52
# object      1
# dtype: int64
# ___________________________________________
# Количество строк - объектов с пропусками 375
# Процент пропусков по всему датафрейму 7.72
#                                           процент пропусков  \
# rougher.state.floatbank10_b_level                       0.0
# rougher.state.floatbank10_d_air                         0.0
# rougher.state.floatbank10_d_level                       0.0
# rougher.state.floatbank10_e_air                         0.0
# rougher.state.floatbank10_e_level                       0.0
# rougher.state.floatbank10_f_air                         0.0
# rougher.state.floatbank10_f_level                       0.0
# rougher.input.floatbank11_sulfate                       0.0
# primary_cleaner.input.sulfate                           0.0
# ...

# %%
info_columns_nan(df_full)
# Out:
# Количество объектов - строк в датафрейме 19439
# Количество столбцов-признаков в датафрейме 87
# ___________________________________________
# Типы данных
# float64    86
# object      1
# dtype: int64
# ___________________________________________
# Количество строк - объектов с пропусками 4481
# Процент пропусков по всему датафрейму 23.05
#                                           процент пропусков  \
# rougher.output.concentrate_au                           0.0
# rougher.calculation.au_pb_ratio                         0.0
# rougher.output.concentrate_pb                           0.0
# final.output.tail_pb                                    1.0
# rougher.input.feed_pb                                   1.0
# final.output.concentrate_sol                            1.0
# rougher.input.feed_sol                                  1.0
# rougher.input.feed_size                                 1.0
# primary_cleaner.input.xanthate                          1.0
# ...

# %% [markdown]
# Типы данных в каждом датафрейме одинаковые:
#
# - Категориальные: категориальных нет.
#
# - datetime: `date`.
#
# - Количественные: все остальные, тип `float`.
#
# - Логические: логических нет.
#
# В датафрейме `df_train`  14579 объектов  и 87 признаков (характеристик) для них, пропусков много - 20.9%.
#
# В датафрейме `df_test`  4860 объектов  и 53 признака (характеристик) для них, пропусков 7.7%.
#
# В датафрейме `df_full`  19439 объектов  и 87 признака (характеристик) для них, пропусков много - 23.1%.
#
# Позже рассмотрим пропуски, определим причины их возникновения, рассмотрим возможность произвести адекватную замену или удалить часть данных с пропусками.

# %% [markdown]
# Вызывем метод `columns` для изучения корректности названий заголовков датафреймов.

# %%
df_train.columns.tolist()
# Out:
# ['date',
#  'rougher.input.feed_au',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_air',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
# ...

# %%
df_test.columns.tolist()
# Out:
# ['date',
#  'rougher.input.feed_au',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_air',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.xanthate',
# ...

# %%
df_full.columns.tolist()
# Out:
# ['date',
#  'rougher.input.feed_au',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_air',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
# ...

# %% [markdown]
# Беспорядочных имен столбцов нет, пробелы в названиях не используются. В названиях между словами используется разделитель "точка". Оставим авторское название столбцов. Название записаны точно, согласно формата указанного в задании.

# %% [markdown]
# Рассмотрим данные на наличие дубликатов.

# %%
print("Число дубликатов в df_train:", df_train.duplicated().sum())
print("Число дубликатов в df_test:", df_test.duplicated().sum())
print("Число дубликатов в df_full:", df_full.duplicated().sum())
# Out:
# Число дубликатов в df_train: 0
# Число дубликатов в df_test: 0
# Число дубликатов в df_full: 0

# %% [markdown]
# Проанализируем признаки, отсутсвующие в тестовой выборке, какие этапы описывают и к какому типу относятся.

# %%
set(df_train.columns) - set(df_test.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# В тесте из 34 пропущенных признака (9 пропущенных признаков этапа `final`, 8 `primary_cleaner`, 9 `rougher`, 4 `secondary_cleaner`): 30 относятся к параметрам продукта  и только 4 к расчетным характеристикам.
#
# То есть нет типа признака `output` - это целевые признаки (отсутствуют данные по всем этапам обработки сырья):
#
# - на всех этапах отсутствует информация о хвостовых частях,
#
# - на всех этапах, кроме повторной очистки отсутствует информация о доле металлов,
#
# - на финальном этапе и этапе флотации отсутствуют признаки эфеективности обогащения,
#
# - отсутствуют данные о некоторых реагентах на этапе флотации.
#
# В тесте отсутствуют типы признака `calculation` для этапа `rougher` (расчетная характеристика), скорее всего эти данные рассчитываются позднее и не доступны во время процесса.

# %% [markdown]
# **Вывод**
#
# - импортировали необходимые библиотеки,
#
# - сохранили содержимое `CSV` в датафреймы,
#
# - получили первые данные о содержании датафреймов, пропуска, дубликатах.
#
#
# Данные состоят из информации о концентрациях металлов на различных стадиях.
#
# Типы данных: `object`, `float`.
#
# Дубликатов нет, пропуски есть во всех датафреймах: `df_train`  - 20.9%, `df_test` - 7.7%, `df_full` - 23.1%.
#
# Количество столбцов-признаков в датафрейме `df_test` меньше, чем в датафрейме `df_test`. Отсутствуют целевые признаки (типа признака `output`) и тип признака `calculation` для этапа `rougher`. Отсутствующие столбцы являются выходными данными на разных этапах промышленной обработки для разных металлов. Выходные значения не нужны для обучения и тестирования модели машинного обучения.

# %% [markdown]
# <a id = 'recovery'></a>

# %% [markdown]
# ### Проверка правильности расчета эффективность обогащения.

# %% [markdown]
# Введем переменные для расчета, расчитаем эффективность обогащения и сравним с фактическими данными `rougher.output.recovery` на тренировочной выборке на сырых данных.

# %%
# введем переменные для расчета эффективности обогащения на этапе rougher - флотация
C = df_train["rougher.output.concentrate_au"]
F = df_train["rougher.input.feed_au"]
T = df_train["rougher.output.tail_au"]

# %%
# расчета эффективности обогащения на тренировочной выборке
calculated_recovery_train = C*(F-T)*100/(F*(C-T))

# %%
# расчитаем МАЕ
output_recovery_train = df_train['rougher.output.recovery']
mean_absolute_error(output_recovery_train, calculated_recovery_train)
# Out:
# 1.1181885454685472e-14

# %% [markdown]
# `MAE` имеет очень малое отклонение - это значит, что расчетное значение эффективность обогащения  совпадает с данными из столбца `rougher.output.recovery`.

# %% [markdown]
# **Вывод**
#
# Средняя абсолютная ошибка составляет 1.1181885454685472e-14, значение очень мало. Это указывает на то, что значение параметра `recovery` в датафрейме `df_train` рассчитано верно.

# %% [markdown]
# <a id = 'columns'></a>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# В задание есть указание, что соседние по времени параметры часто похожи. Воспользуемся этим и заполним пропуски, используя соседние значения.

# %%
# выведем стат показатели для сравнения с данными после заполнения пропусков
df_train['rougher.input.feed_sol'].describe()
# Out:
# count    14502.000000
# mean        36.561420
# std          5.209823
# min          0.010000
# 25%         34.093951
# 50%         37.097511
# 75%         39.899799
# max         53.475325
# Name: rougher.input.feed_sol, dtype: float64

# %%
# заменим пропуски на значение "вперед"
df_train = df_train.fillna(method='ffill')
df_test = df_test.fillna(method='ffill')
df_full = df_full.fillna(method='ffill')

# %%
# проверим корректность замены
df_train.isnull().values.any(), df_test.isnull().values.any()
# Out:
# (False, False)

# %%
df_train.isnull().sum()
# Out:
# date                      0
# rougher.input.feed_au     0
# rougher.input.feed_ag     0
# rougher.input.feed_pb     0
# rougher.input.feed_sol    0
#                          ..
# final.output.recovery     0
# final.output.tail_au      0
# final.output.tail_ag      0
# final.output.tail_pb      0
# final.output.tail_sol     0
# Length: 87, dtype: int64

# %%
info_columns_nan(df_train)
# Out:
# Количество объектов - строк в датафрейме 14579
# Количество столбцов-признаков в датафрейме 87
# ___________________________________________
# Типы данных
# float64    86
# object      1
# dtype: int64
# ___________________________________________
# Количество строк - объектов с пропусками 0
# Процент пропусков по всему датафрейму 0.0
#                                                     процент пропусков  \
# rougher.output.tail_sol                                           0.0
# rougher.output.tail_pb                                            0.0
# rougher.output.tail_ag                                            0.0
# rougher.input.floatbank11_sulfate                                 0.0
# rougher.output.tail_au                                            0.0
# rougher.output.concentrate_sol                                    0.0
# rougher.output.concentrate_pb                                     0.0
# rougher.output.concentrate_ag                                     0.0
# ...

# %%
# выведем стат показатели после заполнения пропусков
df_train['rougher.input.feed_sol'].describe()
# Out:
# count    14579.000000
# mean        36.545646
# std          5.221540
# min          0.010000
# 25%         34.076253
# 50%         37.091668
# 75%         39.885734
# max         53.475325
# Name: rougher.input.feed_sol, dtype: float64

# %% [markdown]
# Стат показатели практически не изменились.

# %% [markdown]
# Нам нужно спрогнозировать сразу две величины:
#
# - эффективность обогащения чернового концентрата `rougher.output.recovery`,
#
# - эффективность обогащения финального концентрата `final.output.recovery`.
#
# Посмотрим на из распределение, постороим гистограмму.

# %%
# вызываем метод что б постоить график распредления эффективности
hist_columns(df_train['rougher.output.recovery'], df_train['final.output.recovery'], 
             'Эффективность обогащения', 'эффективности на этапе флотация и фанальная')

# %% [markdown]
# График показываетe у двух гистограмм небольшое смещение в право среднего и медианы и длинный левый хвот на минимальных значениях, а так же, что на финальном этапе эффективность меньше чем на этапе флотации.
#
# Нужно разобраться, что из себя представляют нулевые значения эффективности на этих двух этапах.
#
# Выведем статистические показатели по всем столбцам датафрейма `df_train`.

# %%
df_train.describe()
# Out:
#        rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# count           14579.000000           14579.000000           14579.000000
# mean                8.352941               8.877460               3.592094
# std                 1.934376               1.922536               1.068227
# min                 0.010000               0.010000               0.010000
# 25%                 6.932996               7.341922               2.868687
# 50%                 8.225284               8.715859               3.524599
# 75%                 9.832210              10.255843               4.253958
# max                13.731330              14.596026               7.052325
#
#        rougher.input.feed_sol  rougher.input.feed_rate  \
# count            14579.000000             14579.000000
# mean                36.545646               474.284502
# std                  5.221540               108.540067
# min                  0.010000                 0.002986
# ...

# %%
df_train[df_train['rougher.output.recovery'] == 0].head()
# Out:
#                    date  rougher.input.feed_au  rougher.input.feed_ag  \
# 36  2016-01-16 12:00:00               7.114065               7.521974
# 37  2016-01-16 13:00:00               7.651522               7.313187
# 38  2016-01-16 14:00:00               5.587750               7.934791
# 39  2016-01-16 15:00:00               4.752992               7.756881
# 40  2016-01-16 16:00:00               5.122801               5.393466
#
#     rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 36               2.811569               41.154430               581.605260
# 37               2.973841               41.983063               562.972841
# 38               1.763437               41.983063               229.379445
# 39               1.025762               11.816724               228.510521
# 40               1.824835               28.380274               550.606559
#
#     rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %% [markdown]
# В пяти объектах датафрейма `df_trai`n наблюдаем нули не только в столбце `rougher.output.recovery`, но и в столбцах, которые показывают содержание металлов к конце этапа флорации:`rougher.output.concentrate_au`, `rougher.output.concentrate_ag`, `rougher.output.concentrate_pb`, `rougher.output.concentrate_sol` . При этом, изначально сырье на этапе флорации показывает не малое содержание металлов в сырье, а на конец всех этапов - тоже есть данные о значительном содежании металлов. Значит имеет место техническая ошибка при выгрузке данных или ошибка оператора при записи данных.

# %%
df_train[df_train['final.output.recovery'] == 0].head()
# Out:
#                     date  rougher.input.feed_au  rougher.input.feed_ag  \
# 516  2016-02-08 00:00:00               5.598971               7.407737
# 943  2016-02-26 17:00:00               7.786147               8.098125
# 944  2016-02-26 18:00:00               7.499248               7.832467
# 945  2016-02-26 19:00:00               7.032278               7.600277
# 946  2016-02-26 20:00:00               7.021635               7.436860
#
#      rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 516               1.934178               31.762853               500.087438
# 943               2.588661               34.896012               502.314489
# 944               2.435125               34.196525               501.677628
# 945               2.265148               31.994985               502.999469
# 946               2.265435               32.541806               501.128474
#
#      rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %% [markdown]
# В пяти объектах датафрейма `df_train` наблюдаем нули не только в столбце `final.output.recovery`, но и в столбцах, которые показывают содержание металлов к конце всех этапов:`final.output.concentrate_au`, `final.output.concentrate_ag`, `final.output.concentrate_pb`, `final.output.concentrate_sol`. При этом, изначально сырье  и на всех этапах показывает не малое содержание металлов в сырье. Значит имеет место техническая ошибка при выгрузке данных или ошибка оператора при записи данных.

# %% [markdown]
# Попробуем найти отсутствующие данные в датафрейме df_full на примере дух объектов из разных выборок.

# %%
df_full.loc[(df_full['date'] == '2016-01-16 12:00:00')|(df_full['date'] == '2016-02-26 17:00:00')]
# Out:
#                     date  rougher.input.feed_au  rougher.input.feed_ag  \
# 36   2016-01-16 12:00:00               7.114065               7.521974
# 943  2016-02-26 17:00:00               7.786147               8.098125
#
#      rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 36                2.811569               41.154430               581.605260
# 943               2.588661               34.896012               502.314489
#
#      rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 36                 65.620714                          13.322740
# 943                49.985298                           8.842907
#
#      rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  \
# 36                             7.504592                       999.026619
# 943                            7.265263                      1000.621368
#
#      rougher.state.floatbank10_a_level  rougher.state.floatbank10_b_air  \
# ...

# %% [markdown]
# В выборке `df_full` значения так же равну нулю. Удалим эти объекты, так как предложить адекватную замену мы не сможем, не будем искажать данные.

# %%
df_train = df_train.drop(df_train[df_train['rougher.output.recovery'] == 0].index)
df_train = df_train.drop(df_train[df_train['final.output.recovery'] == 0].index)

# %%
# проверили факт удаления
df_train[df_train['rougher.output.recovery'] == 0].head()
# Out:
# Empty DataFrame
# ...

# %%
# проверили факт удаления
df_train[df_train['final.output.recovery'] == 0].head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# **Вывод**
#
# На этапе предобработки данных заполнили пропуски в столбцах датафреймов `df_train` и `df_test`, используя соседние значения.
#
# Посмотрели на распределение данных (постороили гистограмму) двух ключевых показателей, по которым нужно будет строить прогноз : `rougher.output.recovery` и  `final.output.recovery`. Обнаружили не значительное количество анамальных нулевых значений. Данные с нулями в этих столбцах удалили.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# <a id = 'metals'></a>

# %% [markdown]
# ### Анализ изменения концентрация металлов (Au, Ag, Pb) на различных этапах очистки

# %% [markdown]
# Построим распределения концентраций металов на различных этапах: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Вызовем метод `distplot_metals()`, он позволит визуализировать изменения концетрации металлов по процессам.

# %%
#метод визуализирует на графиках процессов изменения концетрации металлов  (Au, Ag, Pb) внутри процесса
distplot_metals(CONCENTRATE_METRICS, METALS)

# %%
# метод визуализирует изменения концетрации каждого металла  (Au, Ag, Pb) на разных процессах
distplot_metals(METALS, CONCENTRATE_METRICS)

# %% [markdown]
# Значение концентрации `Au` равномерно увеличивается на протяжении всех стадии очистки.
#
# Концентрация `Ag` увеличивается в черновом концентрате, а в дальнейшем начинает падать.
#
# Концентрация `Pb` незначительно увеличивается на протяжении всех стадий.
#
# У всех металлов распределение показывает длинные хвосты слева и наблюдается не большое количество выбросов в нулевом значении. Особенно сильно нули проявляются после первой очистки у всех металлов. Возможно это говорит о неудачной обработке и весь ценный металл уходит в хвосты.

# %% [markdown]
# **Вывод**
#
# Концентрация золота в от этапа к этапу возрастает (в 10 раз).
#
# Цель флотации и очисток увеличить концентрацию золота оправдывает себя.

# %% [markdown]
# Рассмотрим выбросы. Построим боксплот.

# %%
df_train_rougher_input = pd.DataFrame()
df_train_rougher_output = pd.DataFrame()
df_train_primary_cleaner_output = pd.DataFrame()
df_train_final_output = pd.DataFrame()

# выборка столбцов с концентрацией металлов по процессам
df_train_rougher_input = df_train[['rougher.input.feed_au', 'rougher.input.feed_ag', 
                                   'rougher.input.feed_pb']]
df_train_rougher_output = df_train[['rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 
                                    'rougher.output.concentrate_pb']]
df_train_primary_cleaner_output = df_train[['primary_cleaner.output.concentrate_au', 'primary_cleaner.output.concentrate_ag', 
                                            'primary_cleaner.output.concentrate_pb']]
df_train_final_output = df_train[['final.output.concentrate_au', 'final.output.concentrate_ag', 
                                  'final.output.concentrate_pb']]

# %%
# построим боксплот для каждого вида металла по этапам
boxplot_df(df_train_rougher_input, 'Боксплот концентрация металлов в сырье')
boxplot_df(df_train_rougher_output, 'Боксплот концентрация металлов в черновом концентрате')
boxplot_df(df_train_primary_cleaner_output, 'Боксплот концентрация металлов в концентрате после первой очистки')
boxplot_df(df_train_final_output, 'Боксплот концентрация металлов в финальном концентрате')

# %% [markdown]
# Боксплот показывает, что в столбцах есть данные, выходящие за границы нормальных значений. Эти данные будут мешать модели обучаться, отвлекая её. Поэтому их необходимо удалить.
#
# Объем выбросов от начальной стадии до конечной растет по всем видам металлов.
#
# Удалим выбросы, но модели машинного обучения будем рассматривать как на сырых данных, так и на отчищенных от выбросов.
#
# Нет смысла удалять аномалии из тестовой выборки, поскольку они не могут испортить качество модели, по ним модель может вернуть лишь неверные предсказания.

# %%
 # копия датафрейма обучающей выборки, на которой проведем удаление выбросов
df_train_cut = df_train.copy()

# столбцы с выбросами
outlier_columns = [(df_train_cut, 'rougher.input.feed_au', 'на этапе сырье'), 
                   (df_train_cut, 'rougher.output.concentrate_au', 'на этапе черновой концентрат'), 
                   (df_train_cut, 'primary_cleaner.output.concentrate_au', 'на этапе после первой очистки'),                    
                   (df_train_cut, 'final.output.concentrate_au', 'на этапе финальный концентрат'), 
                   (df_train_cut, 'rougher.input.feed_pb', 'на этапе сырье'), 
                   (df_train_cut, 'rougher.output.concentrate_pb', 'на этапе черновой концентрат'), 
                   (df_train_cut, 'primary_cleaner.output.concentrate_pb', 'на этапе после первой очистки'),                    
                   (df_train_cut, 'final.output.concentrate_pb', 'на этапе финальный концентрат'),
                   (df_train_cut, 'rougher.input.feed_ag', 'на этапе сырье'), 
                   (df_train_cut, 'rougher.output.concentrate_ag', 'на этапе черновой концентрат'), 
                   (df_train_cut, 'primary_cleaner.output.concentrate_ag', 'на этапе после первой очистки'),                    
                   (df_train_cut, 'final.output.concentrate_ag', 'на этапе финальный концентрат')]

# удалим выбросы, вызовем метод find_outliers()
for df_cut,column, title in outlier_columns:    
    df_cut = find_outliers(df_cut,column, title)
# Out:
# Границы норамльного размаха 2.54 - 14.21
# Количество строк, выбранных для удаления в столбце  rougher.input.feed_au на этапе сырье :  76
# Процент удаленных данных 0.54
# ___________________________________________________________
# Границы норамльного размаха 14.99 - 25.93
# Количество строк, выбранных для удаления в столбце  rougher.output.concentrate_au на этапе черновой концентрат :  391
# Процент удаленных данных 2.79
# ___________________________________________________________
# Границы норамльного размаха 23.75 - 41.74
# Количество строк, выбранных для удаления в столбце  primary_cleaner.output.concentrate_au на этапе после первой очистки :  554
# Процент удаленных данных 4.07
# ___________________________________________________________
# Границы норамльного размаха 39.32 - 50.4
# Количество строк, выбранных для удаления в столбце  final.output.concentrate_au на этапе финальный концентрат :  640
# Процент удаленных данных 4.90
# ...

# %%
df_train.shape, df_train_cut.shape
# Out:
# ((14089, 87), (11487, 87))

# %% [markdown]
# Больше всего удалили объектов с анамальными значениями по Au (1661 объект - 11.8%), меньше всего удаленных строк пришлось на Ag (178 строк - 1.3%), по металлу Pb удалили 763 строки с выбросами - 5.4%. В целом было удалено 18.5% объекто от всех тренировочной выборки. Процент удаленных объекто большой, но мы избавились от выбросов в датафрейме.

# %% [markdown]
# <a id = 'metals_size'></a>

# %% [markdown]
# ### Анализ распределения размеров гранул исходного сырья на обучающей и тестовой выборках.

# %% [markdown]
# Сравним распределения размеров гранул исходного сырья на обучающей и тестовой выборках.
#
# Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
#вызываем метод, что б постоить график частоты распредления размеров гранул исходного сырья на обучающей и тестовой выборках
hist_columns(df_train['rougher.input.feed_size'], df_test['rougher.input.feed_size'], 
             'Размер гранул сырья', 'размеров гранул сырья перед флотацией')

# %%
fig = plt.subplots(figsize=(15, 5))
sns.distplot(df_train['rougher.input.feed_size'], bins=15, color='c',)
sns.distplot(df_test['rougher.input.feed_size'], bins=15, color='r',)
plt.title('График плотности распределения гранул сырья перед флотацией')
plt.legend(['train', 'test'])
plt.xlabel('Размер гранул сырья')
plt.ylabel('Плотность')
plt.show()

# %% [markdown]
# Распределение гранул до флотации похоже на нормальное со смещением влево как в обучающей, так и в тестовой выборке.
#
# В тренировочной выборке преобладают значения около порога 50 и выше, в то же время как в тестовой выборке достаточно большое количество объектов сконцентрированы до порога 50.
#
# Обращают на себя внимание множество выбросов (до 380-490) после размера гранул 100-150.

# %% [markdown]
# **Вывод**
#
# Данные о размерах гранул на тестовой и обучающей выборке практически не отличаются.
#
# Ожидаем, что оценка модели будет правильной.

# %% [markdown]
# ### Суммарная концентрация металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.

# %% [markdown]
# Рассмотрим суммарную концентрацию металлов на всех стадиях производства.

# %%
df_train_sum = pd.DataFrame()

# суммарная концентрация металлов на стадии
df_train_sum['rougher.input.feed_sum'] = df_train[['rougher.input.feed_au', 
                                                   'rougher.input.feed_ag', 
                                                   'rougher.input.feed_pb']].sum(axis=1)
df_train_sum['rougher.output.concentrate_sum'] = df_train[['rougher.output.concentrate_au', 
                                                           'rougher.output.concentrate_ag', 
                                                           'rougher.output.concentrate_pb']].sum(axis=1)
df_train_sum['primary_cleaner.output.concentrate_sum'] = df_train[['primary_cleaner.output.concentrate_au', 
                                                                   'primary_cleaner.output.concentrate_ag', 
                                                                   'primary_cleaner.output.concentrate_pb']].sum(axis=1)
df_train_sum['final.output.concentrate_sum'] = df_train[['final.output.concentrate_au', 
                                                         'final.output.concentrate_ag', 
                                                         'final.output.concentrate_pb']].sum(axis=1)

# %%
# вызовем метод и построим гистограммы, которые покажут как менялась суммарная концентрация металлов по этапам
hist_columns(df_train_sum['rougher.input.feed_sum'], df_train_sum['rougher.output.concentrate_sum'], 
             'Суммарная концентрация металлов', 'cуммарной концентрации металлов на разных этапах ')
hist_columns(df_train_sum['primary_cleaner.output.concentrate_sum'], df_train_sum['final.output.concentrate_sum'], 
             'Суммарная концентрация металлов', 'cуммарной концентрации металлов на разных этапах ')

# %% [markdown]
# Суммарная концентрация металлов растет с от процесса к процессу.

# %% [markdown]
# Наблюдаем в каждом процессе левый хвост, уходящий в ноль. Такие данные на каждом этапе показывают, что не все эксперименты проходят успешно, хотя доля их не значительная.
#
# Если на этапе сырье хвост не значительный, то все последующие этапы показывают длинный левый хвост. Это говорит о том, что суммарная концентрация металлов имеет большие выбросы и от этапа к этапу они растут. То есть процес обогащения золота не лишен неудачных экпрериментов.
#
# Учтем этот факт в дальнейшей работе.

# %% [markdown]
# **Вывод**
#
# Суммарная концентрация металлов растет с от процесса к процессу.
#
# Наблюдаем в каждом процессе длинный левый хвост, уходящий в ноль.
#
# В столбцах по концентрации металлов есть данные, выходящие за границы нормальных значений.
#
# Объем выбросов от начальной стадии до конечной растет по всем видам металлов.
#
# Удалили выбросы только по данным концентрации каждого металла в отдельности на каждом этапе. Создали дополнительный датафрейм с очищенными данными на тренировочной  выборке.

# %% [markdown]
# ## Построение модели

# %% [markdown]
# <a id = 'split'></a>

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# Преобразуем столбец `date` в индекс во всех датафореймах.

# %%
df_test = df_test.set_index('date')
df_train_cut = df_train_cut.set_index('date')
df_train = df_train.set_index('date')
df_full = df_full.set_index('date')

# %% [markdown]
# Добавим целевые признаки датасету `df_test` из датасета `df_full` используя индекс `date`.

# %%
print(df_test.shape)
df_test = df_test.join(df_full[TARGETS].loc[df_test.index], how='left')
print(df_test.shape)
# Out:
# (4860, 52)
# (4860, 54)

# %% [markdown]
# Удачно добавили два дополнительных столбца с целевыми признаками.

# %% [markdown]
# Посмотрим на получившийся порядок столбцов датасете `df_test`

# %%
df_test.columns
# Out:
# Index(['rougher.input.feed_au', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_sol',
#        'rougher.input.feed_rate', 'rougher.input.feed_size',
#        'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate', 'rougher.state.floatbank10_a_air',
#        'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
#        'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
#        'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
#        'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
#        'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
#        'rougher.state.floatbank10_f_level',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
# ...

# %% [markdown]
# Добавленны столбцы заняли место в конце датасета, учтем это в дальнейшей работе.

# %% [markdown]
# Удалим из датасета `df_train` признаки, которые относятся к параметрам продукта и типы признака calculation для этапа rougher (расчетная характеристика), то есть те, которых нет в датасете `df_test`. Это 32 признака.

# %%
df_train = df_train.drop((set(df_train.columns) - set(df_test.columns)), axis='columns')
df_train_cut = df_train_cut.drop((set(df_train_cut.columns) - set(df_test.columns)), axis='columns')
print('Размер выборки df_train после удаления столбцов', df_train.shape)
print('Размер выборки df_train_cut после удаления столбцов', df_train_cut.shape)
print('Размер выборки df_test после удаления столбцов', df_test.shape)
# Out:
# Размер выборки df_train после удаления столбцов (14089, 54)
# Размер выборки df_train_cut после удаления столбцов (11487, 54)
# Размер выборки df_test после удаления столбцов (4860, 54)

# %% [markdown]
# Построим матрицу корреляции, определим, если в датасете признаки с высокой корреляцией.

# %%
correlation_matrix = df_train.corr()
correlation_matrix.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# Данных в матрице корреляции много, быстрый просмотр показал, что признаки с высокой корреляцие присутствуют. Отберем признаки с корреляцией более 0.8.

# %%
#создадим массивы признаков
correlated_i = []
correlated_j = []

#создадим массив значений корреляции
correlated_values = []

#переберем признаки и в массивы запишем те, чья корреляция больше 0,7
for i in range(len(correlation_matrix.columns)):    
    for j in range(len(correlation_matrix.columns)):        
        if ((abs(correlation_matrix.iloc[i,j]) >0.8) & (abs(correlation_matrix.iloc[i,j]) != 1.0)):            
            colname_i = correlation_matrix.columns[i]               
            colname_j = correlation_matrix.columns[j]            
            values = correlation_matrix.iloc[i,j]            
            correlated_i.append(colname_i)                        
            correlated_j.append(colname_j)                        
            correlated_values.append(values)
            
#создадим массивы для объединения данных по признакам, чья корреляция больше 0,7                        
data = []
data.append(correlated_i)
data.append(correlated_j)
data.append(correlated_values)

#создадим датафрейм и передадим данные по признакам, чья корреляция больше 0,7   
corr_table_top = pd.DataFrame(data). transpose ()
corr_table_top.columns =['признак_1', 'признак_2', 'значение корреляции']
corr_table_top.head(10)
# Out:
#                             признак_1                           признак_2  \
# 0               rougher.input.feed_au               rougher.input.feed_ag
# 1               rougher.input.feed_ag               rougher.input.feed_au
# 2   rougher.input.floatbank10_sulfate   rougher.input.floatbank11_sulfate
# 3  rougher.input.floatbank10_xanthate  rougher.input.floatbank11_xanthate
# 4     rougher.state.floatbank10_b_air     rougher.state.floatbank10_c_air
# 5     rougher.state.floatbank10_b_air     rougher.state.floatbank10_d_air
# 6     rougher.state.floatbank10_b_air     rougher.state.floatbank10_e_air
# 7     rougher.state.floatbank10_b_air     rougher.state.floatbank10_f_air
# 8   rougher.state.floatbank10_b_level   rougher.state.floatbank10_c_level
# 9   rougher.state.floatbank10_b_level   rougher.state.floatbank10_d_level
#
#   значение корреляции
# 0            0.838611
# 1            0.838611
# 2            0.814304
# 3            0.881752
# 4            0.937305
# ...

# %%
#выведем уникальные значения по пеовому признаку в датафрейме   
corr_table_top['признак_1'].unique()
# Out:
# array(['rougher.input.feed_au', 'rougher.input.feed_ag',
#        'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.state.floatbank10_b_air',
#        'rougher.state.floatbank10_b_level',
#        'rougher.state.floatbank10_c_air',
#        'rougher.state.floatbank10_c_level',
#        'rougher.state.floatbank10_d_air',
#        'rougher.state.floatbank10_d_level',
#        'rougher.state.floatbank10_e_air',
#        'rougher.state.floatbank10_e_level',
#        'rougher.state.floatbank10_f_air',
#        'rougher.state.floatbank10_f_level',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
# ...

# %% [markdown]
# Анализ показал, что в датасете наблюдается мультиколинеарность признаков. Признаков с высокой корреляцией много. Практически все они относятся к данным воздуха и воды на флотационной установке на разных этапах.
#
# Мы можем все эти признаки удалить из выборки или же обьединить и высчитать среднее значение на каждом этапе. Таким образом мы сможем убрать многочисленные признаки с высокой взаимной корреляцией (37 признаков), а вместо них ввести признаки по одному на каждый этап с усреднеными данными.
#
# Объедимин признаки и высчитаем среднее (добавив дополнительно столбцы в выборку), после, удалим не нужные признаки из выборки.

# %%
#сгруппируем столбцы для дальнейшеего объединения и определения среднего
column_set_1 = ['rougher.state.floatbank10_b_air', 'rougher.state.floatbank10_c_air',\
                'rougher.state.floatbank10_d_air', 'rougher.state.floatbank10_e_air',\
                'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_a_air']
column_set_2 = ['rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_level',
                'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_level',
                'rougher.state.floatbank10_f_level', 'rougher.state.floatbank10_a_level']
column_set_3 = ['rougher.input.floatbank11_sulfate', 'rougher.input.floatbank10_sulfate']
column_set_4 = ['rougher.input.floatbank10_xanthate', 'rougher.input.floatbank11_xanthate']
column_set_5 = ['primary_cleaner.state.floatbank8_a_air', 'primary_cleaner.state.floatbank8_b_air', 
                'primary_cleaner.state.floatbank8_c_air', 'primary_cleaner.state.floatbank8_d_air']
column_set_6 = ['primary_cleaner.state.floatbank8_a_level', 'primary_cleaner.state.floatbank8_b_level', 
                'primary_cleaner.state.floatbank8_c_level', 'primary_cleaner.state.floatbank8_d_level']
column_set_7 = ['secondary_cleaner.state.floatbank2_a_air', 'secondary_cleaner.state.floatbank2_b_air', 
                'secondary_cleaner.state.floatbank3_a_air', 'secondary_cleaner.state.floatbank3_b_air', 
                'secondary_cleaner.state.floatbank4_a_air', 'secondary_cleaner.state.floatbank4_b_air', 
                'secondary_cleaner.state.floatbank5_a_air', 'secondary_cleaner.state.floatbank5_b_air', 
                'secondary_cleaner.state.floatbank6_a_air']
column_set_8 = ['secondary_cleaner.state.floatbank2_a_level', 'secondary_cleaner.state.floatbank2_b_level', 
                'secondary_cleaner.state.floatbank3_a_level', 'secondary_cleaner.state.floatbank3_b_level', 
                'secondary_cleaner.state.floatbank4_a_level', 'secondary_cleaner.state.floatbank5_a_level', 
                'secondary_cleaner.state.floatbank5_b_level', 'secondary_cleaner.state.floatbank6_a_level', 
                'secondary_cleaner.state.floatbank4_b_level']
column_set_9 = ['rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb'] 

#создадим словарь: ключ - новый столбец, значения - группа столбцов
dict_features = {
    'rougher.state.floatbank_air': column_set_1, 
    'rougher.state.floatbank_level' : column_set_2, 
    'rougher.input.floatbank_sulfate' : column_set_3, 
    'rougher.input.floatbank_xanthate' : column_set_4, 
    'primary_cleaner.state.floatbank_air' : column_set_5, 
    'primary_cleaner.state.floatbank_level' : column_set_6, 
    'secondary_cleaner.state.floatbank_air' : column_set_7, 
    'secondary_cleaner.state.floatbank_level' : column_set_8, 
    'rougher.input.feed_au_ag_pb' : column_set_9}

# %% [markdown]
# Вызовем метод `change_to_mean()`, создадим новый столбец - среднее значение по сгруппированным столбцам, удалим ненужные столбцы.

# %%
#создаем дополнительные датафреймы с учетом сгруппированых признаков.
df_train_corr = df_train.copy()
df_train_corr  = change_to_mean(df_train_corr, dict_features)
df_train_cut_corr = df_train_cut.copy()
df_train_cut_corr  = change_to_mean(df_train_cut_corr, dict_features)
df_test_corr = df_test.copy()
df_test_corr  = change_to_mean(df_test_corr, dict_features)

# выведем полученную размерность датафреймов после обработки
df_train_corr.shape, df_train_cut_corr.shape, df_test_corr.shape
# Out:
# ((14089, 18), (11487, 18), (4860, 18))

# %%
df_train_corr.columns.tolist()
# Out:
# ['rougher.input.feed_sol',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.output.recovery',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.xanthate',
#  'final.output.recovery',
#  'rougher.state.floatbank_air',
#  'rougher.state.floatbank_level',
#  'rougher.input.floatbank_sulfate',
#  'rougher.input.floatbank_xanthate',
#  'primary_cleaner.state.floatbank_air',
#  'primary_cleaner.state.floatbank_level',
#  'secondary_cleaner.state.floatbank_air',
#  'secondary_cleaner.state.floatbank_level',
#  'rougher.input.feed_au_ag_pb']

# %%
df_train_cut_corr.columns.tolist()
# Out:
# ['rougher.input.feed_sol',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.output.recovery',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.xanthate',
#  'final.output.recovery',
#  'rougher.state.floatbank_air',
#  'rougher.state.floatbank_level',
#  'rougher.input.floatbank_sulfate',
#  'rougher.input.floatbank_xanthate',
#  'primary_cleaner.state.floatbank_air',
#  'primary_cleaner.state.floatbank_level',
#  'secondary_cleaner.state.floatbank_air',
#  'secondary_cleaner.state.floatbank_level',
#  'rougher.input.feed_au_ag_pb']

# %%
df_test_corr.columns.tolist()
# Out:
# ['rougher.input.feed_sol',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.xanthate',
#  'rougher.output.recovery',
#  'final.output.recovery',
#  'rougher.state.floatbank_air',
#  'rougher.state.floatbank_level',
#  'rougher.input.floatbank_sulfate',
#  'rougher.input.floatbank_xanthate',
#  'primary_cleaner.state.floatbank_air',
#  'primary_cleaner.state.floatbank_level',
#  'secondary_cleaner.state.floatbank_air',
#  'secondary_cleaner.state.floatbank_level',
#  'rougher.input.feed_au_ag_pb']

# %% [markdown]
# Посмотрим еще раз на матрицу корреляции с новыми признаками.

# %%
correlation_matrix_new = df_train_corr.corr()
correlation_matrix_new.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_1a58e_row0_col0, #T_1a58e_row1_col1, #T_1a58e_row2_col2, #T_1a58e_row3_col3, #T_1a58e_row4_col4, #T_1a58e_row5_col5, #T_1a58e_row6_col6, #T_1a58e_row7_col7, #T_1a58e_row8_col8, #T_1a58e_row9_col9, #T_1a58e_row10_col10, #T_1a58e_row11_col11, #T_1a58e_row12_col12, #T_1a58e_row13_col13, #T_1a58e_row14_col14, #T_1a58e_row15_col15, #T_1a58e_row16_col16, #T_1a58e_row17_col17 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1a58e_row0_col1 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_1a58e_row0_col2, #T_1a58e_row8_col13, #T_1a58e_row11_col16, #T_1a58e_row17_col13 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_1a58e_row0_col3, #T_1a58e_row10_col9, #T_1a58e_row10_col13, #T_1a58e_row11_col0 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_1a58e_row0_col4, #T_1a58e_row12_col5 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_1a58e_row0_col5, #T_1a58e_row5_col3 {
#   background-color: #fdc574;
# ...

# %% [markdown]
# В результате группировки столбцов с высокой корреляцией, получили новые столбцы.
#
# Выборка существенно уменьшилась.
#
# Мы получили новые признаки. Признаков с высокой корреляцией уже нет, корреляция признаков на усредненных данных с целевыми признаками не изменилась.

# %% [markdown]
# Выделим независимые признаки и целевые зависимые показатели `rougher.output.recovery` и `final.output.recovery` на тестовой выборке.

# %% [markdown]
# Вызовем метод `select_target_scaled_features()`, отделим независимые признаки и целевой признак, масштабируем назависимые признаки.
#
# У нас получится несколько выборок:
#
# - обучающие выборки на сырых (не очищенных) данных (с мультиколлинеарностью признаков) с независимыми признаками для предсказания целевого признака :
#
#     - `rougher.output.recovery` на немасштабированных данных,
#
#     - `final.output.recovery` на немасштабированных данных,
#
#     - `rougher.output.recovery` на масштабированных данных,
#
#     - `final.output.recovery` на масштабированных данных,
#
# - обучающие выборки на сырых (не очищенных) данных (без коллинеарных признаков) с независимыми признаками для предсказания целевого признака :
#
#     - `rougher.output.recovery` на немасштабированных данных,
#
#     - `final.output.recovery` на немасштабированных данных,
#
#     - `rougher.output.recovery` на масштабированных данных,
#
#     - `final.output.recovery` на масштабированных данных,
#
# - обучающие выборки очищенных от выбросов данных (с мультиколлинеарностью признаков) с независимыми признаками для предсказания целевого признака :
#
#     - `rougher.output.recovery` на немасштабированных данных,
#
#     - `final.output.recovery` на немасштабированных данных,
#
#     - `rougher.output.recovery` на масштабированных данных,
#
#     - `final.output.recovery` на масштабированных данных,
#
# - обучающие выборки очищенных от выбросов данных (без коллинеарных признаков) с независимыми признаками для предсказания целевого признака :
#
#     - `rougher.output.recovery` на немасштабированных данных,
#
#     - `final.output.recovery` на немасштабированных данных,
#
#     - `rougher.output.recovery` на масштабированных данных,
#
#     - `final.output.recovery` на масштабированных данных.

# %% [markdown]
# Выделим признаки для работы с целевой переменной `rougher.output.recovery`

# %%
columns_rougher_output_recovery = ['rougher.input.feed_au', 'rougher.input.feed_ag', 
                                   'rougher.input.feed_pb', 'rougher.input.feed_sol',
                                   'rougher.input.feed_rate', 'rougher.input.feed_size',
                                   'rougher.input.floatbank10_sulfate',
                                   'rougher.input.floatbank10_xanthate', 'rougher.state.floatbank10_a_air',
                                   'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
                                   'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
                                   'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
                                   'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
                                   'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
                                   'rougher.state.floatbank10_f_level', 'rougher.input.floatbank11_sulfate',
                                   'rougher.input.floatbank11_xanthate']
columns_corr_rougher_output_recovery = ['rougher.input.feed_sol', 'rougher.input.feed_rate', 
                                        'rougher.input.feed_size', 'rougher.state.floatbank_air', 
                                        'rougher.state.floatbank_level', 'rougher.input.floatbank_sulfate', 
                                        'rougher.input.floatbank_xanthate', 'rougher.input.feed_au_ag_pb']

# %%
#метод разделит датафрейм на признаки (X) и целевую переменную (y).Создаст набор датафреймов для обучения
def select_target(df, targets, columns_recovery):
    
    # Выделим независимые признаки и целевой признак для этапа флотации
    X_rougher = df[columns_recovery]    
    y_rougher = df[targets].iloc[:,0]
    
    # Выделим независимые признаки и целевой признак для финального этапа
    X_final = df.drop(df[targets], axis = 1)        
    y_final = df[targets].iloc[:,1] 
    
    # нарушен порядок следования столбцов, применим сортировку столбцов по имени
    X_rougher = X_rougher[sorted(X_rougher.columns )]    
    X_final = X_final[sorted(X_final.columns )]    
    
    # создаем наборы для обучения
    X_y_rougher_final = [X_rougher, y_rougher, X_final, y_final]            
    return X_y_rougher_final

# %%
# метод для масштабирования признаков (учли возможность масштабирования тестовой выборки)
def scaled_features(df_for_scaled, df_for_learning):        
    # создадим копию выборки с независимыми признаками для дальнейшей стандартизации данных
    X_rougher_scaled = df_for_scaled[0].copy()    
    X_final_scaled = df_for_scaled[2].copy()
    scaler = StandardScaler()
    scaler.fit(df_for_learning[0])
    
    # Масштабирование набора данных ( с учетом того, что возможно придется масштабировать тестовую выборку)
    X_rougher_scaled = scaler.transform(X_rougher_scaled)    
    scaler.fit(df_for_learning[2])    
    X_final_scaled = scaler.transform(X_final_scaled)    
    
    # создаем наборы для обучения с масштабированными данными
    X_y_rougher_final_scaled = [X_rougher_scaled, df_for_scaled[1], X_final_scaled, df_for_scaled[3]]            
    return X_y_rougher_final_scaled

# %%
# получим наборы для тренировки моделей по целевым признакам rougher.output.recovery, final.output.recovery
# на сырых масштабированных и не масштабированных данных (с мультиколлинеарностью признаков)
X_y_train_rougher_final= select_target(df_train, TARGETS, columns_rougher_output_recovery)
X_y_train_rougher_final_scaled= scaled_features(X_y_train_rougher_final, X_y_train_rougher_final)

# получим наборы для тренировки моделей по целевым признакам rougher.output.recovery, final.output.recovery
# на очищенных масштабированных и не масштабированных данных (с мультиколлинеарностью признаков)
X_y_train_cut_rougher_final= select_target(df_train_cut, TARGETS, columns_rougher_output_recovery)
X_y_train_cut_rougher_final_scaled= scaled_features(X_y_train_cut_rougher_final, X_y_train_cut_rougher_final)

# получим наборы для тренировки моделей по целевым признакам rougher.output.recovery, final.output.recovery
# на сырых масштабированных и не масштабированных данных (без коллинеарных признаков)
X_y_train_corr_rougher_final = select_target(df_train_corr, TARGETS, columns_corr_rougher_output_recovery)
X_y_train_corr_rougher_final_scaled= scaled_features(X_y_train_corr_rougher_final, X_y_train_corr_rougher_final)

# получим наборы для тренировки моделей по целевым признакам rougher.output.recovery, final.output.recovery
# на очищенных масштабированных и не масштабированных данных (без коллинеарных признаков)
X_y_train_cut_corr_rougher_final= select_target(df_train_cut_corr, TARGETS, columns_corr_rougher_output_recovery)
X_y_train_cut_corr_rougher_final_scaled= scaled_features(X_y_train_cut_corr_rougher_final, X_y_train_cut_corr_rougher_final)

# получим наборы для тестирования моделей по целевым признакам rougher.output.recovery, final.output.recovery
# на не масштабированных данных (с мультиколлинеарностью признаков)
X_y_test_rougher_final = select_target(df_test, TARGETS, columns_rougher_output_recovery)

# получим наборы для тестирования моделей по целевым признакам rougher.output.recovery, final.output.recovery
# на не масштабированных данных (без коллинеарных признаков)
X_y_test_corr_rougher_final = select_target(df_test_corr, TARGETS, columns_corr_rougher_output_recovery)

# %% [markdown]
# Сравним размеры входящих выборок и тех, что у нас получились на выходе из метода `select_target_scaled_features()`.

# %%
df_train.shape, df_train_cut.shape, df_test.shape
# Out:
# ((14089, 54), (11487, 54), (4860, 54))

# %%
(X_y_train_rougher_final[0].shape, X_y_train_rougher_final[1].shape, X_y_train_rougher_final[2].shape, 
X_y_train_rougher_final[3].shape, X_y_train_rougher_final_scaled[0].shape, X_y_train_rougher_final_scaled[1].shape, 
X_y_train_rougher_final_scaled[2].shape, X_y_train_rougher_final_scaled[3].shape)
# Out:
# ((14089, 22),
#  (14089,),
#  (14089, 52),
#  (14089,),
#  (14089, 22),
#  (14089,),
#  (14089, 52),
#  (14089,))

# %%
(X_y_train_cut_rougher_final[0].shape, X_y_train_cut_rougher_final[1].shape, X_y_train_cut_rougher_final[2].shape, 
X_y_train_cut_rougher_final[3].shape, X_y_train_cut_rougher_final_scaled[0].shape, X_y_train_cut_rougher_final_scaled[1].shape, 
X_y_train_cut_rougher_final_scaled[2].shape, X_y_train_cut_rougher_final_scaled[3].shape)
# Out:
# ((11487, 22),
#  (11487,),
#  (11487, 52),
#  (11487,),
#  (11487, 22),
#  (11487,),
#  (11487, 52),
#  (11487,))

# %%
(X_y_train_corr_rougher_final[0].shape, X_y_train_corr_rougher_final[1].shape, X_y_train_corr_rougher_final[2].shape, 
X_y_train_corr_rougher_final[3].shape, X_y_train_corr_rougher_final_scaled[0].shape, 
X_y_train_corr_rougher_final_scaled[1].shape, X_y_train_corr_rougher_final_scaled[2].shape, 
X_y_train_corr_rougher_final_scaled[3].shape)
# Out:
# ((14089, 8),
#  (14089,),
#  (14089, 16),
#  (14089,),
#  (14089, 8),
#  (14089,),
#  (14089, 16),
#  (14089,))

# %%
(X_y_train_cut_corr_rougher_final[0].shape, X_y_train_cut_corr_rougher_final[1].shape, 
 X_y_train_cut_corr_rougher_final[2].shape, X_y_train_cut_corr_rougher_final[3].shape, 
 X_y_train_cut_corr_rougher_final_scaled[0].shape, X_y_train_cut_corr_rougher_final_scaled[1].shape, 
 X_y_train_cut_corr_rougher_final_scaled[2].shape, X_y_train_cut_corr_rougher_final_scaled[3].shape)
# Out:
# ((11487, 8),
#  (11487,),
#  (11487, 16),
#  (11487,),
#  (11487, 8),
#  (11487,),
#  (11487, 16),
#  (11487,))

# %%
(X_y_test_corr_rougher_final[0].shape, X_y_test_corr_rougher_final[1].shape, 
 X_y_test_corr_rougher_final[2].shape, X_y_test_corr_rougher_final[3].shape)
# Out:
# ((4860, 8), (4860,), (4860, 16), (4860,))

# %%
(X_y_test_rougher_final[0].shape, X_y_test_rougher_final[1].shape, 
 X_y_test_rougher_final[2].shape, X_y_test_rougher_final[3].shape)
# Out:
# ((4860, 22), (4860,), (4860, 52), (4860,))

# %% [markdown]
# Размеры получились в  соответствии с преобразованиям.

# %% [markdown]
# **Вывод**
#
# Выделили зависимые признаки и целевые в отдельные выборки.
#
# Использовали несколько датафреймов для подготовки наборов для обучения: датафреймы с неочищенными от выбросов и очищенными от выбросов данными и датафреймы с тестовыми данными.
#
# Так же выделили наборы с масштабированными и не масштабированными данными.
#
# Проверили признаки на коллинеарность, избавились от коллиреарности в признаках.
#
# Проведем обучение моделей и проверим какие результат дадут очищенные и не очищенные от выбросов выборки, а так же выборки с масштабированными и не масшабированными данными, датафреймы без коллинеарности признаков.
#
# Валидационную выборку выделять не будем, воспользуемся кросс-валидацией.

# %% [markdown]
# <a id = 'metrics'></a>

# %% [markdown]
# ### Метрики

# %% [markdown]
# Реализуем расчет метрики `sMAPE`

# %%
def sMAPE(y_true,y_pred):
    error = np.mean(np.abs(y_true - y_pred)/((np.abs(y_true)+np.abs(y_pred))/2))*100
    return error

# %%
def final_sMAPE(sMAPE_rougher,sMAPE_final):
    total_sMAPE = 0.25*sMAPE_rougher + 0.75*sMAPE_final
    return total_sMAPE

# %% [markdown]
# Создадим `scorer` для того, чтобы использовать его при кросс-валидации

# %%
smape_scorer = make_scorer(sMAPE,greater_is_better=False)

# %% [markdown]
# <a id = 'train'></a>

# %% [markdown]
# ### Обучение моделей и оценка их качества кросс-валидацией

# %% [markdown]
# Обучим модели алгоритмов машинного обучения Дерево Решений, Случайный Лес и Линейная Регрессия, посмотрим, какая даст лучшее значение `итоговое sMAPE`.
#
# Вызовем метод `model_training()` для обучения моделей, расчета `sMAP`E и итогового `sMAPE` на тренировочной выборке.

# %%
# гиперпараметры Дерева Решений
params_dt = {'max_depth': range(1,11)}
model_dt = DecisionTreeRegressor(random_state = STATE)

# модель на немастабированных, неочищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_dt_rougher, best_model_dt_final = \
model_training(X_y_train_rougher_final, model_dt, params_dt, 'нет', 'есть', 'есть', 'Decision_Tree')

# модель на мастабированных, неочищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_dt_rougher_scaled, best_model_dt_final_scaled = \
model_training(X_y_train_rougher_final_scaled, model_dt, params_dt, 'да', 'есть', 'есть', 'Decision_Tree')

# модель на немастабированных, очищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_dt_cut_rougher, best_model_dt_cut_final = \
model_training(X_y_train_cut_rougher_final, model_dt, params_dt, 'нет', 'удалены', 'есть', 'Decision_Tree')

# модель на мастабированных, очищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_dt_cut_rougher_scaled, best_model_dt_cut_final_scaled = \
model_training(X_y_train_cut_rougher_final_scaled, model_dt, params_dt, 'да', 'удалены', 'есть', 'Decision_Tree')

# модель на немастабированных, неочищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_dt_corr_rougher, best_model_dt_corr_final = \
model_training(X_y_train_corr_rougher_final, model_dt, params_dt, 'нет', 'есть', 'нет', 'Decision_Tree')

# модель на мастабированных, неочищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_dt_corr_rougher_scaled, best_model_dt_corr_final_scaled = \
model_training(X_y_train_corr_rougher_final_scaled, model_dt, params_dt, 'да', 'есть', 'нет', 'Decision_Tree')

# модель на немастабированных, очищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_dt_cut_corr_rougher, best_model_dt_cut_corr_final = \
model_training(X_y_train_cut_corr_rougher_final, model_dt, params_dt, 'нет', 'удалены', 'нет', 'Decision_Tree')

# модель на мастабированных, очищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_dt_cut_corr_rougher_scaled, best_model_dt_cut_corr_final_scaled = \
model_training(X_y_train_cut_corr_rougher_final_scaled, model_dt, params_dt, 'да', 'удалены', 'нет', 'Decision_Tree')

# выведем накопительную таблицу с перечнем моделей ( их особенностей) и результатами 
tab_train
# Out:
# Лучшее значение sMAPE :     rougher - 6.310690546618978, final - 9.310749531788826
# Лучшее значениях гиперпараметров:     rougher - DecisionTreeRegressor(max_depth=2,
#                       random_state=RandomState(MT19937) at 0x2283BFEDB40), final - DecisionTreeRegressor(max_depth=2,
#                       random_state=RandomState(MT19937) at 0x2283BFEC840)
# Лучшее значение sMAPE :     rougher - 6.310690546618978, final - 9.310749531788826
# Лучшее значениях гиперпараметров:     rougher - DecisionTreeRegressor(max_depth=2,
#                       random_state=RandomState(MT19937) at 0x2283BFED440), final - DecisionTreeRegressor(max_depth=2,
#                       random_state=RandomState(MT19937) at 0x2283BFEC940)
# Лучшее значение sMAPE :     rougher - 6.236739154207042, final - 8.133013504546557
# Лучшее значениях гиперпараметров:     rougher - DecisionTreeRegressor(max_depth=5,
# ...

# %% [markdown]
# Среди моделей алгоритма машинного обучения Дерево Решений лучше всего себя показала модель очищенная от выбросов. `Итоговое  sMAPE` на тренировочной выборке - 7.659.
#
# На результат модели положительное влияние оказала очистка данных от выбросов. Масштабирование данных не повлияло на результат, а избавление от мультиколинеарности признаков ухудшило показатели.

# %%
# гиперпараметры Случайный Лес
params_rf = {'n_estimators': range(12, 23, 2), 'max_depth' : [1,10]}
model_rf = RandomForestRegressor(random_state = STATE)

# модель на немастабированных, неочищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_rf_rougher, best_model_rf_final = \
model_training(X_y_train_rougher_final, model_rf, params_rf, 'нет', 'есть', 'есть', 'Random_Forest')

# модель на мастабированных, неочищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_rf_rougher_scaled, best_model_rf_final_scaled = \
model_training(X_y_train_rougher_final_scaled, model_rf, params_rf, 'да', 'есть', 'есть', 'Random_Forest')

# модель на немастабированных, очищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_rf_cut_rougher, best_model_rf_cut_final = \
model_training(X_y_train_cut_rougher_final, model_rf, params_rf, 'нет', 'удалены', 'есть', 'Random_Forest')

# модель на мастабированных, очищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_rf_cut_rougher_scaled, best_model_rf_cut_final_scaled = \
model_training(X_y_train_cut_rougher_final_scaled, model_rf, params_rf, 'да', 'удалены', 'есть', 'Random_Forest')

# модель на немастабированных, неочищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_rf_corr_rougher, best_model_rf_corr_final = \
model_training(X_y_train_corr_rougher_final,  model_rf, params_rf, 'нет', 'есть', 'нет', 'Random_Forest')

# модель на мастабированных, неочищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_rf_corr_rougher_scaled, best_model_rf_corr_final_scaled = \
model_training(X_y_train_corr_rougher_final_scaled, model_rf, params_rf, 'да', 'есть', 'нет', 'Random_Forest')

# модель на немастабированных, очищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_rf_cut_corr_rougher, best_model_rf_cut_corr_final = \
model_training(X_y_train_cut_corr_rougher_final, model_rf, params_rf, 'нет', 'удалены', 'нет', 'Random_Forest')

# модель на мастабированных, очищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_rf_cut_corr_rougher_scaled, best_model_rf_cut_corr_final_scaled = \
model_training(X_y_train_cut_corr_rougher_final_scaled, model_rf, params_rf, 'да', 'удалены', 'нет', 'Random_Forest')

# выведем накопительную таблицу с перечнем моделей ( их особенностей) и результатами 
tab_train
# Out:
# Лучшее значение sMAPE :     rougher - 6.476511166466736, final - 9.2834093284095
# Лучшее значениях гиперпараметров:     rougher - RandomForestRegressor(max_depth=10, n_estimators=18,
#                       random_state=RandomState(MT19937) at 0x2283BFEEA40), final - RandomForestRegressor(max_depth=1, n_estimators=18,
#                       random_state=RandomState(MT19937) at 0x2283BFEEB40)
# Лучшее значение sMAPE :     rougher - 6.4768340955034365, final - 9.283409328409498
# Лучшее значениях гиперпараметров:     rougher - RandomForestRegressor(max_depth=10, n_estimators=18,
#                       random_state=RandomState(MT19937) at 0x2283BFEEC40), final - RandomForestRegressor(max_depth=1, n_estimators=18,
#                       random_state=RandomState(MT19937) at 0x2283BFEED40)
# Лучшее значение sMAPE :     rougher - 5.854468129970561, final - 8.11839214068755
# Лучшее значениях гиперпараметров:     rougher - RandomForestRegressor(max_depth=10, n_estimators=22,
# ...

# %% [markdown]
# Среди моделей алгоритма машинного обучения Случайный Лес лучше всего себя показала модель очищенная от выбросов на  немасштабированных данных. `Итоговое sMAPE` на тренировочной выборке - 7.552. Полученный результат лучше, чем у алгоритма Дерево Решений.
#
# На результат модели положительное влияние оказала очистка данных от выбросов. Масштабирование данных практически не повлияло на результат, а избавление от мультиколинеарности признаков немного улучшило показатели.

# %%
# гиперпараметры Линейная Регрессия
params_lr = {}
model_lr = LinearRegression()

# модель на немастабированных, неочищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_lr_rougher, best_model_lr_final = \
model_training(X_y_train_rougher_final, model_lr, params_lr, 'нет', 'есть', 'есть', 'Linear_Regression')

# модель на мастабированных, неочищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_lr_rougher_scaled, best_model_lr_final_scaled = \
model_training(X_y_train_rougher_final_scaled, model_lr, params_lr, 'да', 'есть', 'есть', 'Linear_Regression')

# модель на немастабированных, очищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_lr_cut_rougher, best_model_lr_cut_final = \
model_training(X_y_train_cut_rougher_final, model_lr, params_lr, 'нет', 'удалены', 'есть', 'Linear_Regression')

# модель на мастабированных, очищенных от выбросов с мультиколинеарностью данных
tab_train.loc[len(tab_train.index)], best_model_lr_cut_rougher_scaled, best_model_lr_cut_final_scaled = \
model_training(X_y_train_cut_rougher_final_scaled, model_lr, params_lr, 'да', 'удалены', 'есть', 'Linear_Regression')

# модель на немастабированных, неочищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_lr_corr_rougher, best_model_lr_corr_final = \
model_training(X_y_train_corr_rougher_final, model_lr, params_lr, 'нет', 'есть', 'нет', 'Linear_Regression')

# модель на мастабированных, неочищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_lr_corr_rougher_scaled, best_model_lr_corr_final_scaled = \
model_training(X_y_train_corr_rougher_final_scaled, model_lr, params_lr, 'да', 'есть', 'нет', 'Linear_Regression')

# модель на немастабированных, очищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_lr_cut_corr_rougher, best_model_lr_cut_corr_final = \
model_training(X_y_train_cut_corr_rougher_final, model_lr, params_lr, 'нет', 'удалены', 'нет', 'Linear_Regression')

# модель на мастабированных, очищенных от выбросов данныхб без мультиколинеарности признаков
tab_train.loc[len(tab_train.index)], best_model_lr_cut_corr_rougher_scaled, best_model_lr_cut_corr_final_scaled = \
model_training(X_y_train_cut_corr_rougher_final_scaled, model_lr, params_lr, 'да', 'удалены', 'нет', 'Linear_Regression')

# выведем накопительную таблицу с перечнем моделей ( их особенностей) и результатами 
tab_train
# Out:
# Лучшее значение sMAPE :     rougher - 6.484131680991643, final - 9.532101113367673
# Лучшее значениях гиперпараметров:     rougher - LinearRegression(), final - LinearRegression()
# Лучшее значение sMAPE :     rougher - 6.484131680991631, final - 9.532101113367705
# Лучшее значениях гиперпараметров:     rougher - LinearRegression(), final - LinearRegression()
# Лучшее значение sMAPE :     rougher - 6.048230676463016, final - 8.889436786541287
# Лучшее значениях гиперпараметров:     rougher - LinearRegression(), final - LinearRegression()
# Лучшее значение sMAPE :     rougher - 6.0482306764630085, final - 8.889436786541255
# Лучшее значениях гиперпараметров:     rougher - LinearRegression(), final - LinearRegression()
# Лучшее значение sMAPE :     rougher - 6.617439113213772, final - 9.178052704405825
# Лучшее значениях гиперпараметров:     rougher - LinearRegression(), final - LinearRegression()
# Лучшее значение sMAPE :     rougher - 6.617439113213772, final - 9.178052704405825
# ...

# %% [markdown]
# Среди моделей алгоритма машинного обучения Линейная Регрессия лучше всего себя показала модель очищенная от выбросов и  мультколиреарности. `Итоговое sMAPE` на тренировочной выборке -7.614. Полученный результат лучше, чем у алгоритма Дерево Решений, но хуже, чем у алогоритма Случайный Лес.
#
# Все преобразования данных: масштабирование, очистка данных от выбросов и мультиколлинеарности, дали положительные результаты, улучшая результат. Более всего повлияла очистка от выбросов.

# %% [markdown]
# **Вывод**
#
# Лучшая модель на тренировочной выборке Случайный Лес очищенная от выбросов на немасштабированных данных. `Итоговое sMAPE` этой модели - 7.552.

# %% [markdown]
# <a id = 'test'></a>

# %% [markdown]
# ### Проверка модели на тестовой выборке

# %% [markdown]
# Для проверки модели на тестовой выборке постомотрим результаты не только на лучшей отобранной модели - Случайный Лес, но и константной модели.
#
# Масштабировать данные тестовой выборки нет необходимости.

# %% [markdown]
# Вызовем метод `test_scorer()` и посмотрим на результаты, которые покажет лучшая модель.

# %%
#модель Случайный Лес на немасштабированных, очищенных от выбросов данных 
tab_test.loc[len(tab_test.index)] = test_scorer(X_y_train_cut_rougher_final, X_y_test_rougher_final, 
                                                best_model_rf_cut_rougher, best_model_rf_cut_final, 
                                                'нет', 'удалены', 'есть', 'Random_Forest')

# %%
tab_test
# Out:
#   Алгоритм модели Масштабированы  Выбросы Коллирнеарность  sMAPE_rougher  \
# 0   Random_Forest            нет  удалены            есть        3.38465
# 1   Random_Forest            нет  удалены            есть        3.38465
#
#    sMAPE_final  итоговое sMAPE
# 0     8.688032        7.362187
# 1     8.688032        7.362187

# %% [markdown]
# На тестовой выборке лучшая модель - Случайный лес показала качество с итоговым `sMAPE` - 7.362.

# %% [markdown]
# Для сравнения выведем данные показателя класса DummyRegressor, что бы показать насколько может быть обманчива точность.
#
# Проверим модель на адекватность, сравним качество константной модели с качеством предсказания лучшей модели.

# %%
dummy_rougher = DummyRegressor(strategy = "median")
dummy_final = DummyRegressor(strategy = "median")

dummy_rougher.fit(X_y_train_cut_rougher_final[0], X_y_train_cut_rougher_final[1])
dummy_final.fit(X_y_train_cut_rougher_final[2], X_y_train_cut_rougher_final[3])

sMAPE_rougher = sMAPE( X_y_test_rougher_final[1],dummy_rougher.predict(X_y_test_rougher_final[0]))
sMAPE_final = sMAPE( X_y_test_rougher_final[3],dummy_final.predict(X_y_test_rougher_final[2]))
sMAPE_total_dummy = final_sMAPE(sMAPE_rougher,sMAPE_final)

print('Примечание: Качество константной модели на тренировочных данных dummy', sMAPE_total_dummy.round(2))
# Out:
# Примечание: Качество константной модели на тренировочных данных dummy 8.27

# %% [markdown]
# Лучшая модель Случайный лес показала качество лучше, чем константная модель.
#
# Можно сделать **вывод:**
#
# Ошибка на тесте приемлемая (7.362), так как она меньше чем у константной модели (8.27).

# %% [markdown]
# ## Итоги и выводы по проекту

# %% [markdown]
# В рамках проекта были предоставлены "сырые" данные с параметрами добычи и очистки золотосодержащей руды.
#
# Целью проекта является прототип модели машинного обучения для «Цифры» - компании, которая разрабатывает решения для эффективной работы промышленных предприятий. Данная модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Нужно было смоделировать процесс восстановления золота из золотосодержащей руды. Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
#
#
# Данные преставлены в трёх файлах:
#
# `gold_recovery_train.csv` — обучающая выборка;
#
# `gold_recovery_test.csv` — тестовая выборка;
#
# `gold_recovery_full.csv` — исходные данные.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# Типы данных в каждом датафрейме одинаковые: `datetime` и количественные (тип `float`).
#
# В датафрейме `df_train` 14579 объектов и 87 признаков (характеристик) для них, пропусков много - 20.9%.
#
# В датафрейме `df_test` 4860 объектов и 53 признака (характеристик) для них, пропусков 7.7%.
#
# В датафрейме `df_full` 19439 объектов и 87 признака (характеристик) для них, пропусков много - 23.1%.
#
# Дубликатов сторок нет.
#
# Количество столбцов-признаков в датафрейме `df_test` меньше, чем в датафрейме `df_test`. Отсутсвуют целевые признаки (типа признака `output`) и тип признака `calculation` для этапа `rougher`. Отсутствующие столбцы являются выходными данными на разных этапах промышленной обработки для разных металлов. Выходные значения не нужны для обучения и тестирования модели машинного обучения.
#
# Детальную информацию можно посмотреть по ссылке  [общая информация](#df)
#
# Расчитали эффективность обогащения и сравнли с фактическими данными rougher.output.recovery на тренировочной выборке на сырых данных.
#
# **Средняя абсолютная ошибка составили 1.1181885454685472e-14, значение очень мало. Вывод: значение параметра `recovery` в датафрейме df_train рассчитано верно.**
#
# Детальную информацию можно посмотреть по ссылке  [recovery](#recovery)
#
# На этапе предобработки данных заполнили пропуски, используя соседние значения (ссылка на задание: "соседние по времени параметры часто похожи.").
#
# Гистограммы распредления двух признаков: эффективность обогащения чернового концентрата `rougher.output.recovery`, эффективность обогащения финального концентрата `final.output.recovery`, показывают одинакове распределение (небольшое смещение в право среднего и медианы и длинный левый хвот на минимальных значениях). Показывает, что на финальном этапе эффективность меньше чем на этапе флотации.
#
# У некоторых объектов тренировочного датафрейма выявлены нули. Имеет место техническая ошибка при выгрузке данных или ошибка оператора при записи данных. Удалили 8 объектов, так как предьявить адекватную замену смогли, а искажать данные не решились.
#
# Детальную информацию можно посмотреть по ссылке  [предобработка данных](#columns)
#
# Провели анализ изменения концентрация металлов (`Au`, `Ag`, `Pb`) на различных этапах очистки.
#
# наблюдаем следующие изменения на различных этапах:
#
# - значение концентрации `Au` равномерно увеличивается на протяжении всех стадии очистки,
#
# - концентрация `Ag` увеличивается в черновом концентрате, а в дальнейшем начинает падать.
#
# - концентрация `Pb` незначительно увеличивается на протяжении всех стадий.
#
# Наблюдаем некоторое количество выбросов в нулевом значении. Особенно сильно нули проявляются после первой очистки у всех металлов. Возможно это говорит о неудачной обработке в некоторых случаях и весь ценный металл уходит в хвосты.
#
# Можно сделать вывод, что цель флотации и очисток увеличить концентрацию золота оправдывает себя.
#
# Удалили выбросы. Аномалии из тестовой выборки не удаляли, поскольку они не могут испортить качество модели.
#
# Детальную информацию можно посмотреть по ссылке  [концентрация металлов](#metals)
#
# Провели анализ распределения размеров гранул исходного сырья на обучающей и тестовой выборках.
#
# Сделали вывод, что так как данные о размерах гранул на тестовой и обучающей выборке практически не отличаются, ожидаем, что оценка модели будет правильной.
#
# Детальную информацию можно посмотреть по ссылке  [размер гранул](#metals_size)
#
# Сравнили суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Длинный левый хвос на гистограммах, уходящий в ноль показывает, что не все эксперименты проходят успешно, хотя доля их не значительная.
#
# Детальную информацию можно посмотреть по ссылке  [суммарная концентрация мателлов](#metals_size)
#
# На этапе подготовки данных к посторению модели преобровали столбец `date` в индекс во всех датафореймах. В дальнейшем по этому столбцу восстановили данные в тестовой выборке по нескольким столбцам, которые в ней отсутствовали, к примеру целевые признаки.
#
# Удалим из тренировочного датасета признаки, которые относятся к параметрам продукта (32 признаков).
#
# В данных обнаружены независимые признаки с высокой корреляцией друг к дугу. Отобрали признаки с корреляцией более 0.8, обьединили их с аналогисчными по сути признаками в датасете, расчитали среднее значение. Признаки с высокой корреляцией удалили, их заменили признаки с средним значением. Таким образом избавились от мультиколлинеарности в признаках в датасете. Изменения проводили на тренировочной и тестовой выборке.
#
# Отделили независимые признаки и целевые зависимые показатели `rougher.output.recovery` и `final.output.recovery`, масштабировали назависимые признаки.
#
# На этапе обучания моделей будем использовать несколько наборов датафреймов: датафреймы с неочищенными от выбросов и очищенными от выбросов данными и датафреймы, датафреймы и масштабированными и немасштабированными данными, а так же датафреймы с мультиколлинеарностью признаков и  обработанные датафреймы без коллинеарных признаков.
#
# Модели `Дерево Решений` и `Случайный Лес` теоретически не будут реагировать на преобразование датафреймов. Проверили этот на практике.
#
# Валидационную выборку не выделяли, воспользовались кросс-валидацией.
#
# Детальную информацию можно посмотреть по ссылке  [подготовка данных](#split)
#
# Создали метрики `sMAPE` для этапа флотации и `sMAPE` для финального этапа, а так же метрику `итоговое sMAPE` для того, чтобы использовать их в качестве оценки моделей.
#
# Детальную информацию можно посмотреть по ссылке  [метрики](#metrics)
#
# Обучили модели алгоритмов машинного обучения `Дерево Решений`, `Случайный Лес` и `Линейная Регрессия`. Для этого подготовили наборы датафреймов  для тренировки моделей по целевым признакам `rougher.output.recovery`, `final.output.recovery`.
#
# Среди моделей алгоритма машинного обучения `Дерево Решений` лучше всего себя показала модель очищенная от выбросов. `Итоговое  sMAPE` на тренировочной выборке -7.659.
#
# На результат модели положительное влияние оказала очистка данных от выбросов. Масштабирование данных не повлияло на результат, а избавление от мультиколинеарности признаков ухудшило показатели.
#
# Среди моделей алгоритма машинного обучения `Случайный Лес` лучше всего себя показала модель очищенная от выбросов. `Итоговое sMAPE` на тренировочной выборке -7.552. Полученный результат лучший среди всех алгоритмов.
#
# На результат модели положительное влияние оказала очистка данных от выбросов. Масштабирование данных практически не повлияло на результат, а избавление от мультиколинеарности признаков немного улучшило показатели.
#
# Среди моделей алгоритма машинного обучения `Логистическая Регрессия` лучше всего себя показала модель очищенная от выбросов, мультколиреарности. `Итоговое sMAPE` на тренировочной выборке -7.614. Полученный результат лучше, чем у алгоритма Дерево Решений, но хуже, чем у алогоритма Случайный Лес.
#
# Все преобразования данных: масштабирование, очистка данных от выбросов и мультиколлинеарности, дали положительные результаты, улучшая результат. Более всего повлияла очистка от выбросов.
#
# **Итогом  обучения является признание лучшей модели по составленным метрикам  - `Случайный лес` очищенная от выбросов. `Итоговое sMAPE` этой модели -7.552.**
#
# Детальную информацию можно посмотреть по ссылке  [обучение](#train)
#
#
# На тестовой выборке лучшая модель - Случайный Лес показала качество с итоговым sMAPE - 7.362.
#
# Сравнили качство лучшей модели на тестовой выборки с константной моделью. Качество константной модели на тренировочных данных - 8.27 - больше, чем у лучшей модели.
#
# **Можно сделать вывод: ошибка модели Случайный Лес на тестовой выборке приемлемая (7.362), так как она меньше чем у константной модели (8.27).**
#
# Детальную информацию можно посмотреть по ссылке  [проверка та тесте](#test)
